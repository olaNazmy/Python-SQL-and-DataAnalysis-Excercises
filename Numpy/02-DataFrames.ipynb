# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index. Let's use pandas to explore this topic!
#
# * 1) Creating DataFrames
# * 2) Selecting, Creating and Dropping Columns
# * 3) Selecting, Creating and Dropping Rows
# * 4) Selecting subset of rows and columns
# * 5) Selecting by conditions
# * 6) Selecting by data type
# * 7) Set New Index
# * 8) Reset Index

# %%
import pandas as pd
import numpy as np

np.random.seed(101)

# %% [markdown]
# ## 1) Creating DataFrames

# %% [markdown]
# ### Using Numpy Array

# %%
np.random.randn(5,4)
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
df = pd.DataFrame(np.random.randn(5,4), index=['A', 'B', 'C', 'D', 'E'], columns=['W', 'X', 'Y', 'Z'])

# %%
df
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   W        4 non-null      float64
#  1   X        4 non-null      float64
#  2   Y        4 non-null      float64
#  3   Z        4 non-null      float64
#  4   my_list  4 non-null      int64
#  5   new      4 non-null      float64
# dtypes: float64(5), int64(1)
# memory usage: 396.0+ bytes

# %% [markdown]
# ### Using Dictionary

# %%
df2 = pd.DataFrame({'A':[1,2,3],
                  'B':[5,6,7],
                  'C':[1,2,3],
                  'D': [10, 20, 30]}, index=['X', 'Y', 'Z'])

# %%
df2
# Out:
#    A  B  C   D
# X  1  5  1  10
# Y  2  6  2  20
# Z  3  7  3  30

# %% [markdown]
# ## 2) Selecting, Creating and Dropping Columns

# %% [markdown]
# ### Selecting Columns

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df[['X', 'Y']]
# Out:
#           X         Y
# A  1.693723 -1.706086
# B  0.390528  0.166905
# C  0.072960  0.638787
# D -0.754070 -0.943406
# E  1.901755  0.238127

# %%
df['W']
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %%
df['X']
# Out:
# A    1.693723
# B    0.390528
# C    0.072960
# D   -0.754070
# E    1.901755
# Name: X, dtype: float64

# %%
# Pass a list of column names
df[['Z','W', 'X']]
# Out:
#           Z         W         X
# A -1.159119  0.302665  1.693723
# B  0.184502 -0.134841  0.390528
# C  0.329646  0.807706  0.072960
# D  0.484752 -0.497104 -0.754070
# E  1.996652 -0.116773  1.901755

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df['W'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Creating a New Column

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df['my_list'] = [20, 50, 80, 90, 70]

# %%
df
# Out:
#           W         X         Y         Z  my_list
# A  0.302665  1.693723 -1.706086 -1.159119       20
# B -0.134841  0.390528  0.166905  0.184502       50
# C  0.807706  0.072960  0.638787  0.329646       80
# D -0.497104 -0.754070 -0.943406  0.484752       90
# E -0.116773  1.901755  0.238127  1.996652       70

# %%
df['my_np_array'] = np.array([200, 500, 800, 900, 700])
df['empty_column'] = np.nan
df['None_column'] = None
df['no values'] = 'NO'

# %%
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   None_column no values
# A        None        NO
# B        None        NO
# C        None        NO
# D        None        NO
# E        None        NO

# %%
pd.Series([10,20,30,40,50], index=['B', 'A', 'E', 'D', 'C'])
# Out:
# B    10
# A    20
# E    30
# D    40
# C    50
# dtype: int64

# %%
df['my_ser'] = pd.Series([10,20,30,40,50], index=['B', 'A', 'E', 'D', 'C'])

# %%
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   None_column no values  my_ser
# A        None        NO      20
# B        None        NO      10
# C        None        NO      50
# D        None        NO      40
# E        None        NO      30

# %%
df['W'] + df['Y']
# Out:
# A   -1.403420
# B    0.032064
# C    1.446493
# D   -1.440510
# E    0.121354
# dtype: float64

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   None_column no values  my_ser       new
# A        None        NO      20 -1.403420
# B        None        NO      10  0.032064
# C        None        NO      50  1.446493
# D        None        NO      40 -1.440510
# E        None        NO      30  0.121354

# %%
df['plus_5'] = df['my_ser'] + 5
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   None_column no values  my_ser       new  plus_5
# A        None        NO      20 -1.403420      25
# B        None        NO      10  0.032064      15
# C        None        NO      50  1.446493      55
# D        None        NO      40 -1.440510      45
# E        None        NO      30  0.121354      35

# %%
df['my_np_array'] > 600
# Out:
# A    False
# B    False
# C     True
# D     True
# E     True
# Name: my_np_array, dtype: bool

# %%
df['gt_85'] = df['my_np_array'] > 600
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   None_column no values  my_ser       new  plus_5  gt_85
# A        None        NO      20 -1.403420      25  False
# B        None        NO      10  0.032064      15  False
# C        None        NO      50  1.446493      55   True
# D        None        NO      40 -1.440510      45   True
# E        None        NO      30  0.121354      35   True

# %% [markdown]
# ### Droping Columns

# %%
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   None_column no values  my_ser       new  plus_5  gt_85
# A        None        NO      20 -1.403420      25  False
# B        None        NO      10  0.032064      15  False
# C        None        NO      50  1.446493      55   True
# D        None        NO      40 -1.440510      45   True
# E        None        NO      30  0.121354      35   True

# %%
df_1 = df.drop('None_column', axis=1)

# %%
df_1
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   no values  my_ser       new  plus_5  gt_85
# A        NO      20 -1.403420      25  False
# B        NO      10  0.032064      15  False
# C        NO      50  1.446493      55   True
# D        NO      40 -1.440510      45   True
# E        NO      30  0.121354      35   True

# %%
# Not inplace unless specified!
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   None_column no values  my_ser       new  plus_5  gt_85
# A        None        NO      20 -1.403420      25  False
# B        None        NO      10  0.032064      15  False
# C        None        NO      50  1.446493      55   True
# D        None        NO      40 -1.440510      45   True
# E        None        NO      30  0.121354      35   True

# %%
df.drop('None_column', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z  my_list  my_np_array  empty_column  \
# A  0.302665  1.693723 -1.706086 -1.159119       20          200           NaN
# B -0.134841  0.390528  0.166905  0.184502       50          500           NaN
# C  0.807706  0.072960  0.638787  0.329646       80          800           NaN
# D -0.497104 -0.754070 -0.943406  0.484752       90          900           NaN
# E -0.116773  1.901755  0.238127  1.996652       70          700           NaN
#
#   no values  my_ser       new  plus_5  gt_85
# A        NO      20 -1.403420      25  False
# B        NO      10  0.032064      15  False
# C        NO      50  1.446493      55   True
# D        NO      40 -1.440510      45   True
# E        NO      30  0.121354      35   True

# %%
df.drop(columns = ['my_ser', 'my_np_array', 'gt_85', 'plus_5'], axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# A  0.302665  1.693723 -1.706086 -1.159119       20           NaN        NO
# B -0.134841  0.390528  0.166905  0.184502       50           NaN        NO
# C  0.807706  0.072960  0.638787  0.329646       80           NaN        NO
# D -0.497104 -0.754070 -0.943406  0.484752       90           NaN        NO
# E -0.116773  1.901755  0.238127  1.996652       70           NaN        NO
#
#         new
# A -1.403420
# B  0.032064
# C  1.446493
# D -1.440510
# E  0.121354

# %% [markdown]
# ## 3) Selecting, Creating and Dropping Rows

# %% [markdown]
# ### Selecting Rows

# %%
df
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# A  0.302665  1.693723 -1.706086 -1.159119       20           NaN        NO
# B -0.134841  0.390528  0.166905  0.184502       50           NaN        NO
# C  0.807706  0.072960  0.638787  0.329646       80           NaN        NO
# D -0.497104 -0.754070 -0.943406  0.484752       90           NaN        NO
# E -0.116773  1.901755  0.238127  1.996652       70           NaN        NO
#
#         new
# A -1.403420
# B  0.032064
# C  1.446493
# D -1.440510
# E  0.121354

# %%
# df['W']
columns = ['W', 'Y']
df[columns]
# Out:
#           W         Y
# A  0.302665 -1.706086
# B -0.134841  0.166905
# C  0.807706  0.638787
# D -0.497104 -0.943406
# E -0.116773  0.238127

# %%
# location
df.loc['A']
# Out:
# W               0.302665
# X               1.693723
# Y              -1.706086
# Z              -1.159119
# my_list               20
# empty_column         NaN
# no values             NO
# new             -1.40342
# Name: A, dtype: object

# %%
df.loc['D']
# Out:
# W              -0.497104
# X               -0.75407
# Y              -0.943406
# Z               0.484752
# my_list               90
# empty_column         NaN
# no values             NO
# new             -1.44051
# Name: D, dtype: object

# %% [markdown]
# Or select based off of position instead of label

# %%
# index location
df.iloc[3]
# Out:
# W              -0.497104
# X               -0.75407
# Y              -0.943406
# Z               0.484752
# my_list               90
# empty_column         NaN
# no values             NO
# new             -1.44051
# Name: D, dtype: object

# %%
df.loc[['A', 'C']]
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# A  0.302665  1.693723 -1.706086 -1.159119       20           NaN        NO
# C  0.807706  0.072960  0.638787  0.329646       80           NaN        NO
#
#         new
# A -1.403420
# C  1.446493

# %%
df.iloc[[3, 4]]
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# D -0.497104 -0.754070 -0.943406  0.484752       90           NaN        NO
# E -0.116773  1.901755  0.238127  1.996652       70           NaN        NO
#
#         new
# D -1.440510
# E  0.121354

# %%
df.iloc[2:5]
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# C  0.807706  0.072960  0.638787  0.329646       80           NaN        NO
# D -0.497104 -0.754070 -0.943406  0.484752       90           NaN        NO
# E -0.116773  1.901755  0.238127  1.996652       70           NaN        NO
#
#         new
# C  1.446493
# D -1.440510
# E  0.121354

# %%
df.loc['A']
# Out:
# W               0.302665
# X               1.693723
# Y              -1.706086
# Z              -1.159119
# my_list               20
# empty_column         NaN
# no values             NO
# new             -1.40342
# Name: A, dtype: object

# %%
# df.loc[('C', 'Z')]
df.loc['C', 'Z']
# Out:
# 0.32964629880452445

# %%
df.loc['C']['Z']
# Out:
# 0.32964629880452445

# %%
df.loc['A', 'W']
# Out:
# 0.3026654485851825

# %%
df['W']
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %%
df['W'].loc['A']
# Out:
# 0.3026654485851825

# %%
df
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# A  0.302665  1.693723 -1.706086 -1.159119       20           NaN        NO
# B -0.134841  0.390528  0.166905  0.184502       50           NaN        NO
# C  0.807706  0.072960  0.638787  0.329646       80           NaN        NO
# D -0.497104 -0.754070 -0.943406  0.484752       90           NaN        NO
# E -0.116773  1.901755  0.238127  1.996652       70           NaN        NO
#
#         new
# A -1.403420
# B  0.032064
# C  1.446493
# D -1.440510
# E  0.121354

# %% [markdown]
# ### Creating a New Row

# %%
df
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# A  0.302665  1.693723 -1.706086 -1.159119       20           NaN        NO
# B -0.134841  0.390528  0.166905  0.184502       50           NaN        NO
# C  0.807706  0.072960  0.638787  0.329646       80           NaN        NO
# D -0.497104 -0.754070 -0.943406  0.484752       90           NaN        NO
# E -0.116773  1.901755  0.238127  1.996652       70           NaN        NO
#
#         new
# A -1.403420
# B  0.032064
# C  1.446493
# D -1.440510
# E  0.121354

# %%
df.loc['V'] = [10, 20, 50, 80, 90, np.nan, 'NO', 0.23]

# %%
df
# Out:
#            W          X          Y          Z  my_list  empty_column  \
# A   0.302665   1.693723  -1.706086  -1.159119       20           NaN
# B  -0.134841   0.390528   0.166905   0.184502       50           NaN
# C   0.807706   0.072960   0.638787   0.329646       80           NaN
# D  -0.497104  -0.754070  -0.943406   0.484752       90           NaN
# E  -0.116773   1.901755   0.238127   1.996652       70           NaN
# V  10.000000  20.000000  50.000000  80.000000       90           NaN
#
#   no values       new
# A        NO -1.403420
# B        NO  0.032064
# C        NO  1.446493
# D        NO -1.440510
# E        NO  0.121354
# V        NO  0.230000

# %%
df.loc['H'] = df.loc['A'] + df.loc['B']

# %%
df
# Out:
#            W          X          Y          Z  my_list  empty_column  \
# A   0.302665   1.693723  -1.706086  -1.159119       20           NaN
# B  -0.134841   0.390528   0.166905   0.184502       50           NaN
# C   0.807706   0.072960   0.638787   0.329646       80           NaN
# D  -0.497104  -0.754070  -0.943406   0.484752       90           NaN
# E  -0.116773   1.901755   0.238127   1.996652       70           NaN
# V  10.000000  20.000000  50.000000  80.000000       90           NaN
# H   0.167825   2.084251  -1.539181  -0.974618       70           NaN
#
#   no values       new
# A        NO -1.403420
# B        NO  0.032064
# C        NO  1.446493
# D        NO -1.440510
# E        NO  0.121354
# V        NO  0.230000
# H      NONO -1.371357

# %% [markdown]
# ### Dropping Rows

# %%
df.drop(index = 'H', axis=0)
# Out:
#            W          X          Y          Z  my_list  empty_column  \
# A   0.302665   1.693723  -1.706086  -1.159119       20           NaN
# B  -0.134841   0.390528   0.166905   0.184502       50           NaN
# C   0.807706   0.072960   0.638787   0.329646       80           NaN
# D  -0.497104  -0.754070  -0.943406   0.484752       90           NaN
# E  -0.116773   1.901755   0.238127   1.996652       70           NaN
# V  10.000000  20.000000  50.000000  80.000000       90           NaN
#
#   no values       new
# A        NO -1.403420
# B        NO  0.032064
# C        NO  1.446493
# D        NO -1.440510
# E        NO  0.121354
# V        NO  0.230000

# %%
df
# Out:
#            W          X          Y          Z  my_list  empty_column  \
# A   0.302665   1.693723  -1.706086  -1.159119       20           NaN
# B  -0.134841   0.390528   0.166905   0.184502       50           NaN
# C   0.807706   0.072960   0.638787   0.329646       80           NaN
# D  -0.497104  -0.754070  -0.943406   0.484752       90           NaN
# E  -0.116773   1.901755   0.238127   1.996652       70           NaN
# V  10.000000  20.000000  50.000000  80.000000       90           NaN
# H   0.167825   2.084251  -1.539181  -0.974618       70           NaN
#
#   no values       new
# A        NO -1.403420
# B        NO  0.032064
# C        NO  1.446493
# D        NO -1.440510
# E        NO  0.121354
# V        NO  0.230000
# H      NONO -1.371357

# %%
df.drop('H', axis=0, inplace=True)

# %%
df
# Out:
#            W          X          Y          Z  my_list  empty_column  \
# A   0.302665   1.693723  -1.706086  -1.159119       20           NaN
# B  -0.134841   0.390528   0.166905   0.184502       50           NaN
# C   0.807706   0.072960   0.638787   0.329646       80           NaN
# D  -0.497104  -0.754070  -0.943406   0.484752       90           NaN
# E  -0.116773   1.901755   0.238127   1.996652       70           NaN
# V  10.000000  20.000000  50.000000  80.000000       90           NaN
#
#   no values       new
# A        NO -1.403420
# B        NO  0.032064
# C        NO  1.446493
# D        NO -1.440510
# E        NO  0.121354
# V        NO  0.230000

# %%
df.drop(index = ['E', 'V'], axis=0, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z  my_list  empty_column no values  \
# A  0.302665  1.693723 -1.706086 -1.159119       20           NaN        NO
# B -0.134841  0.390528  0.166905  0.184502       50           NaN        NO
# C  0.807706  0.072960  0.638787  0.329646       80           NaN        NO
# D -0.497104 -0.754070 -0.943406  0.484752       90           NaN        NO
#
#         new
# A -1.403420
# B  0.032064
# C  1.446493
# D -1.440510

# %% [markdown]
# ## 4) Selecting subset of rows and columns

# %%
df.loc['B']['Y']
# Out:
# 0.16690463609281317

# %%
df.loc['B'  , 'Y']
# Out:
# 0.16690463609281317

# %%
# df.loc[['A','B']][['W', 'Y']]

df.loc[   ['A', 'B']  , ['W', 'X']   ]
# Out:
#           W         X
# A  0.302665  1.693723
# B -0.134841  0.390528

# %%
df[['W', 'X']].loc[['A','B']]
# Out:
#           W         X
# A  0.302665  1.693723
# B -0.134841  0.390528

# %% [markdown]
# ## 5) Selecting by conditions
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df = df[['W', 'X', 'Y', 'Z', 'my_list', 'new']]
df
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df > 0
# Out:
#        W      X      Y      Z  my_list    new
# A   True   True  False  False     True  False
# B  False   True   True   True     True   True
# C   True   True   True   True     True   True
# D  False  False  False   True     True  False

# %%
df[df > 0]
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723       NaN       NaN       20       NaN
# B       NaN  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D       NaN       NaN       NaN  0.484752       90       NaN

# %%
df['W'] > 0
# Out:
# A     True
# B    False
# C     True
# D    False
# Name: W, dtype: bool

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493

# %%
df[df['W'] > 0]['Y']
# Out:
# A   -1.706086
# C    0.638787
# Name: Y, dtype: float64

# %%
df[df['W'] > 0][['Y','X']]
# Out:
#           Y         X
# A -1.706086  1.693723
# C  0.638787  0.072960

# %%
df.loc['A', 'Y']
# Out:
# -1.7060859307350775

# %%
df
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df.loc[ ['A', 'B']  ,  ['X', 'Y', 'W'] ]
# Out:
#           X         Y         W
# A  1.693723 -1.706086  0.302665
# B  0.390528  0.166905 -0.134841

# %%
df.loc[df['W'] > 0 , ['X', 'Y']]

# df.loc[ df['W'] > 0 , ['Y','X']]   #  .loc[['A','C']]['X']
# Out:
#           X         Y
# A  1.693723 -1.706086
# C  0.072960  0.638787

# %%
df
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %% [markdown]
# **For two conditions you can use | and & with parenthesis:**

# %%
(df['W'] > 0) & (df['Y'] < 1)
# Out:
# A     True
# B    False
# C     True
# D    False
# dtype: bool

# %%
(df['W'] > 0) | (df['Y'] < 1)
# Out:
# A    True
# B    True
# C    True
# D    True
# dtype: bool

# %%
~(df['W'] > 0) & (df['Y'] < 1)
# Out:
# A    False
# B     True
# C    False
# D     True
# dtype: bool

# %%
# df.loc[  (df['W'] > 0) & (df['Y'] < 1) & (df['Z'] < 1)]

df.loc[ (df['W'] > 0) | (df['Y'] < 1)]
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df.loc[((df['W'] > 0) & (df['my_list'] > 50)) | (df['Y'] < 0) ]
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df[ (df['W'] < 0) | ~(df['Y'] < 1)]
# Out:
#           W         X         Y         Z  my_list       new
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %% [markdown]
# **isin**

# %%
df
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df.loc[(df['my_list'] == 20) | (df['my_list'] == 50)]

# %%
df.loc[(df['my_list'].isin([20, 50]))]
# Out:
#           W         X         Y         Z  my_list       new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064

# %%
df.loc[~(df['my_list'].isin([20, 70]))]
# Out:
#           W         X         Y         Z  my_list       new
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %% [markdown]
# **between**

# %%
df.loc[  (df['my_list'].between(30, 80))  ]
# Out:
#           W         X         Y         Z  my_list       new
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493

# %%
df.loc[  ~(df['my_list'].between(30, 80))  ]
# Out:
#           W         X         Y         Z  my_list      new
# A  0.302665  1.693723 -1.706086 -1.159119       20 -1.40342
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.44051

# %%
df[~(df['my_list'].isin([20, 70]))]
# Out:
#           W         X         Y         Z  my_list       new
# B -0.134841  0.390528  0.166905  0.184502       50  0.032064
# C  0.807706  0.072960  0.638787  0.329646       80  1.446493
# D -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %% [markdown]
# **Quiz**

# %%
my_df = pd.DataFrame(np.random.randn(100, 4), columns=['X', 'Y', 'Z', 'S'])
my_df
# Out:
#            X         Y         Z         S
# 0   1.099550 -1.025499  1.132170 -0.918222
# 1  -1.290992 -0.008876 -0.072111  1.292545
# 2  -0.214258  0.324996 -1.019374 -1.243351
# 3  -0.366681  0.589336  2.619668 -1.064573
# 4   1.826460 -0.287396  1.431274 -1.486898
# ..       ...       ...       ...       ...
# 95 -0.212220  1.330096  0.683211 -0.008983
# 96  0.429693  0.662408  1.223457  0.842224
# 97  2.133137  1.159285 -1.738897  0.134020
# 98  1.040047 -0.200309 -1.560216  0.050336
# 99 -0.611267 -2.231037 -0.125453  1.083252
#
# [100 rows x 4 columns]

# %%
my_df[(my_df['X'] > 0) & (my_df['Z'] < 0)]['S']
# Out:
# 5    -0.276139
# 15    1.119649
# 16   -0.662194
# 18   -0.767988
# 20    2.020620
# 23   -1.382815
# 24   -0.890814
# 29   -1.404220
# 37    1.547742
# 42   -1.019750
# 45   -0.406914
# 46   -0.030757
# 53   -0.196932
# 59   -0.217813
# 61   -0.406113
# 62   -0.276797
# 65   -1.479348
# 68    1.967961
# 69   -1.674672
# 71   -1.280880
# 75   -1.447798
# 83    0.706543
# 85   -0.360401
# 86    0.841790
# 91    0.308671
# 97    0.134020
# 98    0.050336
# Name: S, dtype: float64

# %%
my_df[(my_df['X'] > 0) & (my_df['Z'] < 0)]['S'].iloc[3:9]
# Out:
# 18   -0.767988
# 20    2.020620
# 23   -1.382815
# 24   -0.890814
# 29   -1.404220
# 37    1.547742
# Name: S, dtype: float64

# %%
my_df[(my_df['X'] > 0) & (my_df['Z'] < 0)]['S'].iloc[3:9]
# Out:
# 18   -0.767988
# 20    2.020620
# 23   -1.382815
# 24   -0.890814
# 29   -1.404220
# 37    1.547742
# Name: S, dtype: float64

# %% [markdown]
# ## 6) Selecting by data type

# %% [markdown]
# **Convert columns to best possible dtypes use `convert_dtypes()` or `astype()`**

# %%
df3 = pd.DataFrame(
    {
        "integers": pd.Series([1, 2, 3], dtype=np.dtype("int32")),
        "strings": pd.Series(["x", "y", "z"], dtype=np.dtype("O")),
        "booleans": pd.Series([True, False, np.nan], dtype=np.dtype("O")),
        "strings_2": pd.Series(["h", "i", np.nan], dtype=np.dtype("O")),
        "integers_2": pd.Series([10, 30, 20], dtype=np.dtype("float")),
        "floats": pd.Series([np.nan, 100.5, 200], dtype=np.dtype("float")),
        "dates": pd.Series(['30/7/1993 12:26:13', '30/7/1993 12:26:13', '30/7/1993 12:26:13'], dtype=np.dtype("O"))
    }
)

# %%
df3
# Out:
#    integers strings booleans strings_2  integers_2  floats               dates
# 0         1       x     True         h        10.0     NaN  30/7/1993 12:26:13
# 1         2       y    False         i        30.0   100.5  30/7/1993 12:26:13
# 2         3       z      NaN       NaN        20.0   200.0  30/7/1993 12:26:13

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   integers    3 non-null      int32
#  1   strings     3 non-null      object
#  2   booleans    2 non-null      object
#  3   strings_2   2 non-null      object
#  4   integers_2  3 non-null      float64
#  5   floats      2 non-null      float64
#  6   dates       3 non-null      object
# dtypes: float64(2), int32(1), object(4)
# memory usage: 284.0+ bytes

# %%
df3 = df3.convert_dtypes()
df3
# Out:
#    integers strings  booleans strings_2  integers_2  floats  \
# 0         1       x      True         h          10    <NA>
# 1         2       y     False         i          30   100.5
# 2         3       z      <NA>      <NA>          20   200.0
#
#                 dates
# 0  30/7/1993 12:26:13
# 1  30/7/1993 12:26:13
# 2  30/7/1993 12:26:13

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   integers    3 non-null      Int32
#  1   strings     3 non-null      string
#  2   booleans    2 non-null      boolean
#  3   strings_2   2 non-null      string
#  4   integers_2  3 non-null      Int64
#  5   floats      2 non-null      Float64
#  6   dates       3 non-null      string
# dtypes: Float64(1), Int32(1), Int64(1), boolean(1), string(3)
# memory usage: 275.0 bytes

# %%
df3['integers_2'] = df3['integers_2'].astype('int32')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   integers    3 non-null      Int32
#  1   strings     3 non-null      string
#  2   booleans    2 non-null      boolean
#  3   strings_2   2 non-null      string
#  4   integers_2  3 non-null      int32
#  5   floats      2 non-null      Float64
#  6   dates       3 non-null      string
# dtypes: Float64(1), Int32(1), boolean(1), int32(1), string(3)
# memory usage: 260.0 bytes

# %%
df3['integers'] = df3['integers'].astype('int32')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   integers    3 non-null      int32
#  1   strings     3 non-null      string
#  2   booleans    2 non-null      boolean
#  3   strings_2   2 non-null      string
#  4   integers_2  2 non-null      Int64
#  5   floats      2 non-null      Float64
#  6   dates       3 non-null      string
# dtypes: Float64(1), Int64(1), boolean(1), int32(1), string(3)
# memory usage: 272.0 bytes

# %%
df3
# Out:
#    integers strings  booleans strings_2  integers_2  floats  \
# 0         1       x      True         h          10    <NA>
# 1         2       y     False         i        <NA>   100.5
# 2         3       z      <NA>      <NA>          20   200.0
#
#                 dates
# 0  30/7/1993 12:26:13
# 1  30/7/1993 12:26:13
# 2  30/7/1993 12:26:13

# %%
df3['dates'] = pd.to_datetime(df3['dates'], format="%Y%m/%d %H:%M:%S")
df3
# Out:
#    integers strings  booleans strings_2  integers_2  floats  \
# 0         1       x      True         h          10    <NA>
# 1         2       y     False         i        <NA>   100.5
# 2         3       z      <NA>      <NA>          20   200.0
#
#                 dates
# 0 1993-07-30 12:26:13
# 1 1993-07-30 12:26:13
# 2 1993-07-30 12:26:13

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   integers    3 non-null      int32
#  1   strings     3 non-null      string
#  2   booleans    2 non-null      boolean
#  3   strings_2   2 non-null      string
#  4   integers_2  2 non-null      Int64
#  5   floats      2 non-null      Float64
#  6   dates       3 non-null      datetime64[ns]
# dtypes: Float64(1), Int64(1), boolean(1), datetime64[ns](1), int32(1), string(2)
# memory usage: 272.0 bytes

# %% [markdown]
# **Select with data type**

# %%
df3.select_dtypes(include=['number'])
# Out:
#    integers  integers_2  floats
# 0         1          10    <NA>
# 1         2        <NA>   100.5
# 2         3          20   200.0

# %%
df3.select_dtypes(include=['int32'])
# Out:
#    integers
# 0         1
# 1         2
# 2         3

# %%
df3.select_dtypes(include=['int64'])
# Out:
#    integers_2
# 0          10
# 1        <NA>
# 2          20

# %%
df3.select_dtypes(include=['float32'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
df3.select_dtypes(include=['float64'])
# Out:
#    floats
# 0    <NA>
# 1   100.5
# 2   200.0

# %%
df3.select_dtypes(include=['bool'])
# Out:
#    booleans
# 0      True
# 1     False
# 2      <NA>

# %%
df3.select_dtypes(include=['string'])
# Out:
#   strings strings_2
# 0       x         h
# 1       y         i
# 2       z      <NA>

# %%
df3.select_dtypes(include=['datetime', 'string'])
# Out:
#   strings strings_2               dates
# 0       x         h 1993-07-30 12:26:13
# 1       y         i 1993-07-30 12:26:13
# 2       z      <NA> 1993-07-30 12:26:13

# %%
df3.select_dtypes(exclude=['number'])
# Out:
#   strings  booleans strings_2               dates
# 0       x      True         h 1993-07-30 12:26:13
# 1       y     False         i 1993-07-30 12:26:13
# 2       z      <NA>      <NA> 1993-07-30 12:26:13

# %%
df3.select_dtypes(exclude=['datetime'])
# Out:
#    integers strings  booleans strings_2  integers_2  floats
# 0         1       x      True         h          10    <NA>
# 1         2       y     False         i        <NA>   100.5
# 2         3       z      <NA>      <NA>          20   200.0

# %% [markdown]
# ## 7) Set New Index
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else.

# %%
df
# Out:
#                W         X         Y         Z  my_list       new
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
newind = ['CA', 'NY', 'WY', 'OR']

# %%
df['States'] = newind
# Out:
# <ipython-input-88-b48234e86c04>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['States'] = newind

# %%
df
# Out:
#                W         X         Y         Z  my_list       new States
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420     CA
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064     NY
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493     WY
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510     OR

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z  my_list       new
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df
# Out:
#                W         X         Y         Z  my_list       new States
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420     CA
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064     NY
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493     WY
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510     OR

# %%
df.set_index('States', inplace=True, drop=False)

# %%
df
# Out:
#                W         X         Y         Z  my_list       new States
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420     CA
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064     NY
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493     WY
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510     OR

# %%
df.set_index('Y', inplace=True, drop=False)

# %%
df
# Out:
#                   W         X         Y         Z  my_list       new States
# Y
# -1.706086  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420     CA
#  0.166905 -0.134841  0.390528  0.166905  0.184502       50  0.032064     NY
#  0.638787  0.807706  0.072960  0.638787  0.329646       80  1.446493     WY
# -0.943406 -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510     OR

# %%
df.set_index('W', inplace=True)

# %%
df
# Out:
#                   X         Y         Z  my_list       new States
# W
#  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420     CA
# -0.134841  0.390528  0.166905  0.184502       50  0.032064     NY
#  0.807706  0.072960  0.638787  0.329646       80  1.446493     WY
# -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510     OR

# %%
df.set_index('States', inplace=True)

# %%
df
# Out:
#                W         X         Y         Z  my_list       new
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %% [markdown]
# ## 8) Reset Index
#
# resetting index to numbers

# %%
df
# Out:
#                W         X         Y         Z  my_list       new
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df.reset_index()
# Out:
#   States         W         X         Y         Z  my_list       new
# 0     CA  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# 1     NY -0.134841  0.390528  0.166905  0.184502       50  0.032064
# 2     WY  0.807706  0.072960  0.638787  0.329646       80  1.446493
# 3     OR -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df
# Out:
#                W         X         Y         Z  my_list       new
# States
# CA      0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# NY     -0.134841  0.390528  0.166905  0.184502       50  0.032064
# WY      0.807706  0.072960  0.638787  0.329646       80  1.446493
# OR     -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   States         W         X         Y         Z  my_list       new
# 0     CA  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# 1     NY -0.134841  0.390528  0.166905  0.184502       50  0.032064
# 2     WY  0.807706  0.072960  0.638787  0.329646       80  1.446493
# 3     OR -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %%
df['index'] = list(range(1, 5))
df
# Out:
#   States         W         X         Y         Z  my_list       new  index
# 0     CA  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420      1
# 1     NY -0.134841  0.390528  0.166905  0.184502       50  0.032064      2
# 2     WY  0.807706  0.072960  0.638787  0.329646       80  1.446493      3
# 3     OR -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510      4

# %%
df.set_index('index')
# Out:
#       States         W         X         Y         Z  my_list       new
# index
# 1         CA  0.302665  1.693723 -1.706086 -1.159119       20 -1.403420
# 2         NY -0.134841  0.390528  0.166905  0.184502       50  0.032064
# 3         WY  0.807706  0.072960  0.638787  0.329646       80  1.446493
# 4         OR -0.497104 -0.754070 -0.943406  0.484752       90 -1.440510

# %% [markdown]
# # Great Job!
