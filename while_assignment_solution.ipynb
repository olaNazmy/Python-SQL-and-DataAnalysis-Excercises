# %% [markdown]
# # Quiz

# %% [markdown]
# ###  write a program which count and print the numbers of each character in a string input by console.
#
# Example:
# If the following string is given as input to the program:
#
# abcdefgabc
#
# Then, the output of the program should be:
#
# {a:2,
# c:2,
# b:2,
# e:1,
# d:1,
# g:1,
# f:1}

# %%
str_input = str(input('Enter The String'))
str_input = 'ehab ibrahim '
# Out:
# Enter The Stringehab ibrahim

# %%
dic = {}
str_input = 'ehab ibrahim '
for char in str_input :
    value = str_input.count(char)
    dic[char] = value
dic
# Out:
# {'e': 1, 'h': 2, 'a': 2, 'b': 2, ' ': 2, 'i': 2, 'r': 1, 'm': 1}

# %%
dic = {}
str_input = 'ehab ibrahim '
for i in str_input :
    if i not in dic :
        dic[i] = 1
    else :
        dic[i] += 1
dic
# Out:
# {'e': 1, 'h': 2, 'a': 2, 'b': 2, ' ': 2, 'i': 2, 'r': 1, 'm': 1}

# %% [markdown]
# ### With a given list [12,24,35,24,88,120,155,88,120,155], write a program to print this list after removing all duplicate values

# %%
lst = [12, 24, 35, 24, 88, 120, 155, 88, 120, 155]
# lst = list(set(lst))
# lst

new_lst = []

for i in lst :
    if i in new_lst :
        continue
    else :
        new_lst.append(i)
new_lst
# Out:
# [12, 24, 35, 88, 120, 155]

# %% [markdown]
# ### With two given lists [1,3,6,78,35,55] and [12,24,35,24,88,120,155], write a program to make a list whose elements are intersection of the above given lists.

# %%
lst_1 = [1, 3, 6, 78, 35, 55]
lst_2 = [12, 24, 35, 24, 88, 120, 155]

lst_intersection = []

for i in lst_1 :
    if i in lst_2 :
        lst_intersection.append(i)
lst_intersection
# Out:
# [35]

# %% [markdown]
# ### Concatenate the two lists in one list using zip function and list comprehension
# 	lst_1 = ['a', 'b', 'c', 'd']
# 	lst_2 = ['b', 'c', 'd', 'f']

# %%
lst_1 = ['a', 'b', 'c', 'd']
lst_2 = ['b', 'c', 'd', 'f']

lst = [[i,j] for i, j in zip(lst_1, lst_2)]
lst
# Out:
# [['a', 'b'], ['b', 'c'], ['c', 'd'], ['d', 'f']]

# %% [markdown]
# ### convert the list to dictionary using enumerate function
# 	lst = ['a', 'b', 'c', 'd']
# 	sample_output = {'a' : 1, 'b' : 2}

# %%
lst = ['a', 'b', 'c', 'd']
dict_1 = {value : key for key, value in enumerate(lst, 1) }

# %% [markdown]
# ### calculate the sum of all numbers from 1 to a given number from the user

# %%
x=int(input("enter a number: "))
i=0
for num in range(1, x + 1):
      i += num
print("Sum of numbers is: ", i)
# Out:
# Sum of numbers is:  1275

# %% [markdown]
# ### Count the total number of digits in a number

# %%
n = int(input("Enter number:"))
count = 0
while(n > 0):
    count = count+1
    n = n//10
print("The number of digits in the number are:",count)
# Out:
# The number of digits in the number are: 3

# %% [markdown]
# ### Print list in reverse order using a loop

# %%
list1 = [1, 2, 3, 4, 5, 6, 7]

for i in range(len(list1) - 1, -1, -1):
    print(list1[i])
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ### calculate factorial of a given number

# %%
# To take input from the user
num = int(input("Enter a number: "))

factorial = 1

# check if the number is negative, positive or zero
if num < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1,num + 1):
       factorial = factorial*i
   print("The factorial of",num,"is",factorial)
# Out:
# The factorial of 7 is 5040

# %% [markdown]
# ### Use a loop to display elements from a given list present at odd index positions

# %%
my_list = [31, 42, 13, 34, 85, 0, 99, 1, 3]
print("The list is :")
print(my_list)
print("The elements in odd positions are : ")
for i in range(0, len(my_list), 2):
   print(my_list[i])
# Out:
# The list is :
# [31, 42, 13, 34, 85, 0, 99, 1, 3]
# The elements in odd positions are :
# 31
# 13
# 85
# 99
# 3
